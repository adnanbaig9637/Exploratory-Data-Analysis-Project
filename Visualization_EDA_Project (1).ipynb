# %% [markdown]
# #### Importing the Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings as wr
wr.filterwarnings("ignore")

# %% [markdown]
# #### Importing the dataset

# %%
df = pd.read_csv(r"C:\Users\User\Python-Data Science-Inn\WebScrapping&Data_Cleaning_Project.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Name of Vehicle Brand of Vehicle  Registration Year  \
# 0           0           Hyundai  i20          Hyundai               2012
# 1           1    Hyundai  Elite  i20          Hyundai               2018
# 2           2           Honda  Amaze            Honda               2018
# 3           3      Maruti  Alto  800           Maruti               2015
# 4           4   Hyundai  NEW  SANTRO          Hyundai               2018
#
#   Transmission Fuel type  Kilometers Run   Price Location of Vehicle  \
# 0       Manual    Petrol           92054  377000            Kompally
# 1       Manual    Diesel           89269  763200            Kompally
# 2       Manual    Petrol           97090  605000          Bachupally
# 3       Manual    Petrol           72308  263000          Bachupally
# 4    Automatic    Petrol           92388  433000             Attapur
#
#   Name of City
# 0    Hyderabad
# 1    Hyderabad
# 2    Hyderabad
# 3    Hyderabad
# 4    Hyderabad

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)      #Dropping unwanted column

# %%
df.head()
# Out:
#          Name of Vehicle Brand of Vehicle  Registration Year Transmission  \
# 0           Hyundai  i20          Hyundai               2012       Manual
# 1    Hyundai  Elite  i20          Hyundai               2018       Manual
# 2           Honda  Amaze            Honda               2018       Manual
# 3      Maruti  Alto  800           Maruti               2015       Manual
# 4   Hyundai  NEW  SANTRO          Hyundai               2018    Automatic
#
#   Fuel type  Kilometers Run   Price Location of Vehicle Name of City
# 0    Petrol           92054  377000            Kompally    Hyderabad
# 1    Diesel           89269  763200            Kompally    Hyderabad
# 2    Petrol           97090  605000          Bachupally    Hyderabad
# 3    Petrol           72308  263000          Bachupally    Hyderabad
# 4    Petrol           92388  433000             Attapur    Hyderabad

# %% [markdown]
# ### Visualizations
# #### Univariate Analysis
# #### Numeric Data

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['Registration Year'].plot(kind = 'hist',
                             title = 'Histogram of Registration Year of vehicle',
                             xlabel = 'Registration Year',
                             color = '#bd2b2b',
                             figsize = (6,4))
# Out:
# <Axes: title={'center': 'Histogram of Registration Year of vehicle'}, xlabel='Registration Year', ylabel='Frequency'>

# %% [markdown]
# * From the above plot we can see that most of the vehicles from 2017 year of Registration near about 90 vehicle
# * And also i can see that there is minimum vehicles from 2020 year of registration

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['Kilometers Run'].plot(kind = 'hist',
                             title = 'Histogram of Kilometers Run of vehicle',
                             xlabel = 'Kilometers run',
                             color = '#25e2e6',
                             figsize = (6,4))
# Out:
# <Axes: title={'center': 'Histogram of Kilometers Run of vehicle'}, xlabel='Kilometers run', ylabel='Frequency'>

# %% [markdown]
# * From the above plot i can see that most of the vehicles having Kilometers completed from 40000 to 60000
# * And also i can see that there is minimum vehicles having kilometers completed from 10000 km and 120000 km

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['Price'].plot(kind = 'hist',
                             title = 'Histogram of Price of vehicle',
                             xlabel = 'Prices',
                             color = '#d925e6',
                             figsize = (6,4))
# Out:
# <Axes: title={'center': 'Histogram of Price of vehicle'}, xlabel='Prices', ylabel='Frequency'>

# %% [markdown]
# * From above plot we can see there is most of vehiles prices under 5000000 (5 lakhs)
# * That will be a good insight for us .

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['Registration Year'].plot(kind = 'box',
                             title = 'Box Plot of Registration Year of vehicle',
                             ylabel = 'Registration Year',
                             color = '#bd2b2b',
                             figsize = (6,4))
# Out:
# <Axes: title={'center': 'Box Plot of Registration Year of vehicle'}, ylabel='Registration Year'>

# %% [markdown]
# * From a above Box plot we can see there is no outliers in data
# * And the distance between both whisker is similar and middle line in median so we can see data is normally distributed

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['Kilometers Run'].plot(kind = 'box',
                             title = 'Box plot of Kilometers Run of vehicle',
                             ylabel = 'Kilometers run',
                             color = '#25e2e6',
                             figsize = (6,4))
# Out:
# <Axes: title={'center': 'Box plot of Kilometers Run of vehicle'}, ylabel='Kilometers run'>

# %% [markdown]
# * From a above Box plot we can see there is no outliers in data
# * And the distance between both whisker is similar and middle line in median so we can see data is normally distributed

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['Price'].plot(kind = 'box',
                             title = 'Box Plot of Price of vehicle',
                             ylabel = 'Prices',
                             color = '#d925e6',
                             figsize = (6,4))
# Out:
# <Axes: title={'center': 'Box Plot of Price of vehicle'}, ylabel='Prices'>

# %% [markdown]
# * From a above Box plot we can see there is  outliers in data of prices But it will not affect to my analysis because prices is true values

# %% [markdown]
# #### Categrical Data

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['Brand of Vehicle'].value_counts().plot(kind='barh',
                               color = 'pink',
                               grid = True,
                               width = 0.6,
                               title = 'Bar Plot for Brand of Vehicle',
                               figsize=(8,5),
                               ylabel='Brand of Vehicle',
                               xlabel = 'No of Vehicles')
# Out:
# <Axes: title={'center': 'Bar Plot for Brand of Vehicle'}, xlabel='No of Vehicles', ylabel='Brand of Vehicle'>

# %% [markdown]
# * From the above bar plot we can see there is more vehicles from Maruti Brand more than 175 count
# * And there is minimum cars of KIA, JEEP, SKODA Brand

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['Name of City'].value_counts().plot(kind='barh',
                               color = 'blue',
                               grid = True,
                               width = 0.6,
                               title = 'Bar Plot for City of Cars',
                               figsize=(8,5),
                               ylabel='Name of City',
                               xlabel = 'No of Vehicles')
# Out:
# <Axes: title={'center': 'Bar Plot for City of Cars'}, xlabel='No of Vehicles', ylabel='Name of City'>

# %% [markdown]
# * From the above bar plot we can see there is more vehicles in citys like PATNA, KOLKATA, JAIPUR, AGRA, CHENNAI, BENGALURU, COIMBATORE, SURAT, KOCHI

# %%
df['Fuel type'].value_counts().plot(kind='bar',
                               color = ['pink','white'],
                               grid = True,
                               width = 0.3,
                               title = 'Bar Plot for Fuel type',
                               figsize=(6,4),
                               xlabel='Fuel type',
                               ylabel = 'No of Vehicles')
# Out:
# <Axes: title={'center': 'Bar Plot for Fuel type'}, xlabel='Fuel type', ylabel='No of Vehicles'>

# %% [markdown]
# * From the above plot we can see there is most of the vahicle having Fuel type of Petrol near about 330 count
# * And less vehicles having fuel type of Diesel near about 80 count

# %%
df['Transmission'].value_counts().plot(kind='bar',
                               color = ['yellow','green'],
                               grid = True,
                               width = 0.3,
                               title = 'Bar Plot for Transmission type',
                               figsize=(6,4),
                               xlabel='Transmission type',
                               ylabel = 'No of Vehicles')
# Out:
# <Axes: title={'center': 'Bar Plot for Transmission type'}, xlabel='Transmission type', ylabel='No of Vehicles'>

# %% [markdown]
# * From the above plot we can see there is most of the vahicle having Transmission type of Manual near about 360 count
# * And less vehicles having Transmission of Automatic near about 50 count

# %%
plt.style.use('classic')
plt.style.use('ggplot')
(df['Transmission'].value_counts()/len(df['Transmission'])*100).plot(kind='pie',
                               figsize = (6,5),
                               legend = True,
                               autopct = '%1.1f'+' Percent' ,                   
                               ylabel = 'Transmission',
                               grid = True,
                               title = 'Pie chart for Transmission type in percentage')
# Out:
# <Axes: title={'center': 'Pie chart for Transmission type in percentage'}, ylabel='Transmission'>

# %% [markdown]
# * From above Pie chart we can see the percentages of vehicles transmission
# * There is 86.8 percent of vehicles having Manual Transmission
# * There is 13.2 percent of vehicles having Automatic Transmission

# %%
plt.style.use('classic')
plt.style.use('ggplot')
(df['Fuel type'].value_counts()/len(df['Fuel type'])*100).plot(kind='pie',
                               figsize = (6,5),
                               legend = True,
                               autopct = '%1.1f'+' Percent' ,                   
                               ylabel = 'Fuel type',
                               grid = True,
                               title = 'Pie chart for Fuel type in percentage')
# Out:
# <Axes: title={'center': 'Pie chart for Fuel type in percentage'}, ylabel='Fuel type'>

# %% [markdown]
# * From above Pie chart we can see the percentages of vehicles Fuel type
# * There is 80.9 percent of vehicles having Petrol Fuel type
# * There is 19.1 percent of vehicles having Diesel Fuel type

# %% [markdown]
# #### BiVariate Analysis
# #### Categrical & Categgrical Data

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
plt.figure(figsize=(12,8))
ax = sns.countplot(data = df , y = 'Brand of Vehicle' , hue = 'Transmission',saturation = 0.75)
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# * From above plot we can see Highest vehicle coming from Maruti which is having Manual transmission
# * second highest vehicle coming from Hyundai which is having Manual transmission

# %%
plt.style.use('classic')
plt.style.use('ggplot')
plt.style.use('dark_background')
plt.figure(figsize=(12,8))
ax = sns.countplot(data = df , y = 'Brand of Vehicle' , hue = 'Fuel type')
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# * From above plot we can see Highest vehicle coming from Maruti which is running on petrol near about 153 counts
# * second highest vehicle coming from Hyundai which is running on petrol near about 106 counts

# %% [markdown]
# #### Numeric & Numeric Data

# %%
df.plot('Registration Year','Price',kind='scatter',grid=True,figsize=(8.5,6))
# Out:
# <Axes: xlabel='Registration Year', ylabel='Price'>

# %% [markdown]
# * From the above Scatter plot the direction is positive because if the year of registration increasing so price also increasing
# * And we can see strength is strong because scatter is little close to each other

# %%
df.plot('Registration Year','Kilometers Run',kind='scatter',grid=True,figsize=(8.5,6))
# Out:
# <Axes: xlabel='Registration Year', ylabel='Kilometers Run'>

# %% [markdown]
# * From the above Scatter plot the direction is Negative because if the Kilometers run  increasing so price is decreasing
# * And we can see strength is weak because scatter is not close to each other

# %% [markdown]
# #### Numeric and Categric

# %%
plt.style.use('classic')
plt.style.use('ggplot')
plt.style.use('dark_background')
df.groupby(by='Brand of Vehicle')['Price'].max().plot(kind = 'bar',
                                                      color = '#fc03f4',
                                                      figsize=(6,4),
                                                      ylabel='Prices',
                                                      title = 'Bar plot to check maximum price with brand')
# Out:
# <Axes: title={'center': 'Bar plot to check maximum price with brand'}, xlabel='Brand of Vehicle', ylabel='Prices'>

# %%
plt.style.use('classic')
plt.style.use('ggplot')
plt.style.use('dark_background')
df.groupby(by='Brand of Vehicle')['Price'].min().sort_values().plot(kind = 'bar',
                                                      color = '#fc0366',
                                                      figsize=(6,4),
                                                      ylabel='Prices',
                                                      title = 'Bar plot to check minimum price with brand')
# Out:
# <Axes: title={'center': 'Bar plot to check minimum price with brand'}, xlabel='Brand of Vehicle', ylabel='Prices'>

# %% [markdown]
# #### Analysis based on some conditions

# %%
new = df[
    (df['Registration Year'] > 2015) &
    (df['Transmission'] == 'Manual') &
    (df['Fuel type'] == 'Petrol') &
    (df['Price'] < 500000)].reset_index(drop=True)

# %% [markdown]
# * From above data frame we can conclude we have 74 vehicles having Registration year greater than 2015 and Transmission is Manual, Fuel type is Petrol, Price is less than 500000 .

# %% [markdown]
# #### Multivalriate Analysis
# #### Heatmap

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# * Above Heatmap showing :-
# * Ranges -0.4 to +0.2 represnting Negative correlation which is shown by dark colour
# * Ranges +0.2 to +1.0 respreseting Positive correlation which is shown by light colour

# %%
df.corr(numeric_only=True)
# Out:
#                    Registration Year  Kilometers Run     Price
# Registration Year           1.000000       -0.432525  0.657271
# Kilometers Run             -0.432525        1.000000 -0.179739
# Price                       0.657271       -0.179739  1.000000

# %%
sns.pairplot(df)

# %% [markdown]
# * Pair plot is the combination of scatter plot and histogram
